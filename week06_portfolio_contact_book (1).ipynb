# %%
#A1
Contacts = {
    "John": "0401 765 865",
    "Jacob": "0867 765 754",
    "Tom": "0456 765 983"
}
#A2
Contacts["Jasmeen"] = "0401 103 416"
#A3
Contacts["John"] = "0465 875 865"
#A4
for name,phonenumber in Contacts.items():
  print(f"{name}: {phonenumber}")
# Out:
# John: 0465 875 865
# Jacob: 0867 765 754
# Tom: 0456 765 983
# Jasmeen: 0401 103 416

# %%
#B1
Contacts = {
    "John": {"phone": "0401 765 865", "email": "john@gmail.com"},
     "Jacob": {"phone": "0867 765 754", "email": "jacob@gmail.com"},
     "Tom": {"phone": "0456 765 983", "email": "tom@gmail.com"},
}
#B2
for name, contact_info in Contacts.items():
    print(f"{name}: {contact_info}")
#optional
name_to_lookup = input("Enter the name to look up: ")

if name_to_lookup in Contacts:
    contact_info = Contacts[name_to_lookup]
    print(f"Phone: {contact_info['phone']}")
    print(f"Email: {contact_info['email']}")
else:
    print(f"Contact '{name_to_lookup}' not found.")
# Out:
# John: {'phone': '0401 765 865', 'email': 'john@gmail.com'}
# Jacob: {'phone': '0867 765 754', 'email': 'jacob@gmail.com'}
# Tom: {'phone': '0456 765 983', 'email': 'tom@gmail.com'}
# Enter the name to look up: Tom
# Phone: 0456 765 983
# Email: tom@gmail.com
